# %%
import pandas as pd

df = pd.read_excel('Alonso_2014_SpanishAoA.xls')

df
# Out:
# /Users/gonzalo/anaconda3/envs/main/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#             word  averageAoA        SD  Min  Max  ItemZScore  OralFreq_Log  \
# 0              a        2.28  1.443352    1    6   -1.650147      4.851582
# 1          abajo        2.96  1.369642    1    6   -1.356683      2.615950
# 2     abandonado        6.06  1.658743    2   10   -0.584383      1.623249
# 3      abandonar        7.58  1.654801    4   11   -0.019940      1.806180
# 4       abandono        7.22  1.940860    3   11    0.040498      1.602060
# ...          ...         ...       ...  ...  ...         ...           ...
# 7034       zorra        5.70  2.517287    1   11   -0.231247      0.698970
# 7035       zorro        4.68  2.044804    1   11   -0.601359      1.322219
# 7036        zumo        3.66  1.836256    1    8   -0.944132      0.845098
# ...

# %%
df[[' WrittenFreq_Subtlex-ESP_Log', ' WrittenFreq_LEXESP_Log']].corr()
# Out:
#                              WrittenFreq_Subtlex-ESP_Log  \
# WrittenFreq_Subtlex-ESP_Log                      1.00000
# WrittenFreq_LEXESP_Log                           0.80647
#
#                              WrittenFreq_LEXESP_Log
# WrittenFreq_Subtlex-ESP_Log                 0.80647
# WrittenFreq_LEXESP_Log                      1.00000

# %%
df[[' WrittenFreq_Subtlex-ESP_Log', ' WrittenFreq_LEXESP_Log']].corr('pearson')
# Out:
#                              WrittenFreq_Subtlex-ESP_Log  \
# WrittenFreq_Subtlex-ESP_Log                      1.00000
# WrittenFreq_LEXESP_Log                           0.80647
#
#                              WrittenFreq_LEXESP_Log
# WrittenFreq_Subtlex-ESP_Log                 0.80647
# WrittenFreq_LEXESP_Log                      1.00000

# %%
df[[' WrittenFreq_Subtlex-ESP_Log', ' WrittenFreq_LEXESP_Log']].corr('spearman')
# Out:
#                              WrittenFreq_Subtlex-ESP_Log  \
# WrittenFreq_Subtlex-ESP_Log                     1.000000
# WrittenFreq_LEXESP_Log                          0.795164
#
#                              WrittenFreq_LEXESP_Log
# WrittenFreq_Subtlex-ESP_Log                0.795164
# WrittenFreq_LEXESP_Log                     1.000000
